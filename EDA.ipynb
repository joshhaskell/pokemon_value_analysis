# %% [markdown]
# # Notebook Overview

# %% [markdown]
# The purpose of this notebook is to look at the raw data, understand it's structure and do a general exploration into the characteristics of the data.

# %% [markdown]
# # Import and Read in Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from utilities import *

# %%
df = pd.read_csv('data/raw_pokemon_data.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Overall Characteristics

# %%
summarize_df(df) # This expands a little on the info() method
# Out:
#                       Column  Non-Null Count  Missing Values  \
# 0               card_type_id           29345               0
# 1                       name           29345               0
# 2                         hp           24973            4372
# 3                     rarity           29016             329
# 4                     artist           29056             289
# 5                  supertype           29345               0
# 6                evolvesFrom           10731           18614
# 7                 flavorText           18146           11199
# 8       convertedRetreatCost           23594            5751
# 9             regulationMark            8923           20422
# 10                     rules            7186           22159
# 11               image_small           29345               0
# 12               image_large           29345               0
# 13                    set_id           29345               0
# 14                  set_name           29345               0
# 15                set_series           29345               0
# 16          set_printedTotal           29345               0
# 17                 set_total           29345               0
# 18           set_releaseDate           29345               0
# 19             set_updatedAt           29345               0
# 20  set_legalities_unlimited           29345               0
# 21   set_legalities_expanded           19755            9590
# 22   set_legalities_standard            7253           22092
# 23          set_image_symbol           29345               0
# 24            set_image_logo           29345               0
# 25                    number           29345               0
# 26         ancientTrait_name              94           29251
# 27         ancientTrait_text              94           29251
# 28                    type_1           24903            4442
# 29                    type_2             185           29160
# 30                 subtype_1           29143             202
# 31                 subtype_2            3227           26118
# 32                 subtype_3             413           28932
# 33                 subtype_4              12           29333
# 34     nationalPokedexNumber           24719            4626
# 35             num_abilities            5529           23816
# 36               num_attacks           24944            4401
# 37           num_resistances            7220           22125
# 38            num_weaknesses           24313            5032
# 39                price_type           29345               0
# 40                       low           28416             929
# 41                       mid           28416             929
# 42                      high           28416             929
# 43                    market           28332            1013
# 44                 directLow           11817           17528
#
#     Missing Values (%)    Dtype  Unique Values
# 0                 0.00   object          29345
# 1                 0.00   object           4012
# 2                14.90  float64             32
# 3                 1.12   object             35
# 4                 0.98   object            343
# 5                 0.00   object              3
# 6                63.43   object            828
# 7                38.16   object           4805
# 8                19.60  float64              6
# 9                69.59   object              5
# 10               75.51   object           1703
# 11                0.00   object          17905
# 12                0.00   object          17905
# 13                0.00   object            160
# 14                0.00   object            160
# 15                0.00   object             16
# 16                0.00    int64             91
# 17                0.00    int64            101
# 18                0.00   object            142
# 19                0.00   object             45
# 20                0.00   object              1
# 21               32.68   object              1
# 22               75.28   object              1
# 23                0.00   object            160
# 24                0.00   object            160
# 25                0.00   object           1748
# 26               99.68   object             10
# 27               99.68   object             10
# 28               15.14   object             11
# 29               99.37   object              8
# 30                0.69   object             24
# 31               89.00   object             24
# 32               98.59   object             12
# 33               99.96   object              2
# 34               15.76  float64           1010
# 35               81.16  float64              3
# 36               15.00  float64              4
# 37               75.40  float64              2
# 38               17.15  float64              2
# 39                0.00   object              5
# 40                3.17  float64           2256
# 41                3.17  float64           3009
# 42                3.17  float64           2989
# 43                3.45  float64           3273
# 44               59.73  float64           1517

# %%
# Numeric columns described
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#                  hp convertedRetreatCost set_printedTotal     set_total  \
# count  24973.000000         23594.000000     29345.000000  29345.000000
# mean      97.225003             1.662541       143.894701    160.748645
# std       52.898712             0.857774        52.868999     64.543106
# min       10.000000             0.000000         5.000000      5.000000
# 25%       60.000000             1.000000       106.000000    110.000000
# 50%       80.000000             1.000000       135.000000    146.000000
# 75%      120.000000             2.000000       185.000000    216.000000
# max      340.000000             5.000000       307.000000    304.000000
#
#       nationalPokedexNumber num_abilities   num_attacks num_resistances  \
# count          24719.000000   5529.000000  24944.000000     7220.000000
# mean             371.764473      1.003436      1.632617        1.012881
# std              266.731559      0.069803      0.517787        0.112768
# min                1.000000      1.000000      1.000000        1.000000
# 25%              138.000000      1.000000      1.000000        1.000000
# 50%              324.000000      1.000000      2.000000        1.000000
# 75%              571.000000      1.000000      2.000000        1.000000
# max             1010.000000      3.000000      4.000000        2.000000
#
#       num_weaknesses           low           mid          high        market  \
# count   24313.000000  28416.000000  28416.000000  28416.000000  28332.000000
# mean        1.001563      6.525349      9.064891    130.966001      7.088178
# std         0.039504     60.320168     89.313194   1024.033217     34.804484
# min         1.000000      0.010000      0.050000      0.100000      0.010000
# 25%         1.000000      0.050000      0.230000      1.990000      0.180000
# 50%         1.000000      0.240000      0.500000      4.000000      0.500000
# 75%         1.000000      1.650000      2.870000     11.780000      2.840000
# max         2.000000   4499.990000   8880.300000  10300.000000   2398.950000
#
#           directLow
# count  11817.000000
# mean       5.265564
# std       34.155467
# min        0.010000
# 25%        0.090000
# 50%        0.240000
# 75%        2.000000
# max      999.990000

# %%
pd.set_option('display.max_columns', None)
df.head(2)
# Out:
#               card_type_id    name     hp     rarity           artist  \
# 0         hgss4-1_holofoil  Aggron  140.0  Rare Holo  Kagemaru Himeno
# 1  hgss4-1_reverseHolofoil  Aggron  140.0  Rare Holo  Kagemaru Himeno
#
#   supertype evolvesFrom                                         flavorText  \
# 0   Pokémon      Lairon  You can tell its age by the length of its iron...
# 1   Pokémon      Lairon  You can tell its age by the length of its iron...
#
#    convertedRetreatCost regulationMark rules  \
# 0                   4.0            NaN   NaN
# 1                   4.0            NaN   NaN
#
#                                 image_small  \
# 0  https://images.pokemontcg.io/hgss4/1.png
# 1  https://images.pokemontcg.io/hgss4/1.png
#
#                                       image_large set_id       set_name  \
# 0  https://images.pokemontcg.io/hgss4/1_hires.png  hgss4  HS—Triumphant
# 1  https://images.pokemontcg.io/hgss4/1_hires.png  hgss4  HS—Triumphant
#
#                set_series  set_printedTotal  set_total set_releaseDate  \
# 0  HeartGold & SoulSilver               102        103      2010/11/03
# 1  HeartGold & SoulSilver               102        103      2010/11/03
#
#          set_updatedAt set_legalities_unlimited set_legalities_expanded  \
# 0  2018/03/04 10:35:00                    Legal                     NaN
# 1  2018/03/04 10:35:00                    Legal                     NaN
#
#   set_legalities_standard                               set_image_symbol  \
# 0                     NaN  https://images.pokemontcg.io/hgss4/symbol.png
# 1                     NaN  https://images.pokemontcg.io/hgss4/symbol.png
#
#                                 set_image_logo number ancientTrait_name  \
# 0  https://images.pokemontcg.io/hgss4/logo.png      1               NaN
# 1  https://images.pokemontcg.io/hgss4/logo.png      1               NaN
#
#   ancientTrait_text type_1 type_2 subtype_1 subtype_2 subtype_3 subtype_4  \
# 0               NaN  Metal    NaN   Stage 2       NaN       NaN       NaN
# 1               NaN  Metal    NaN   Stage 2       NaN       NaN       NaN
#
#    nationalPokedexNumber  num_abilities  num_attacks  num_resistances  \
# 0                  306.0            NaN          2.0              1.0
# 1                  306.0            NaN          2.0              1.0
#
#    num_weaknesses       price_type   low   mid  high  market  directLow
# 0             1.0         holofoil  1.69  3.14  4.49    2.59       3.90
# 1             1.0  reverseHolofoil  1.99  2.40  4.80    2.40       3.07

# %% [markdown]
# ### Numerical Columns

# %%
# List of numeric columns
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Separate discrete and continuous columns
discrete_columns = ['convertedRetreatCost']
continuous_columns = [col for col in numeric_columns if col not in discrete_columns]

# Bar Plots for Discrete Columns
plt.figure(figsize=(15, 10))
for i, col in enumerate(discrete_columns, 1):
    plt.subplot(3, 4, i)
    df[col].value_counts().sort_index().plot(kind='bar', edgecolor='k')
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Adjust grid size dynamically based on the number of continuous columns
n_cols = 4
n_rows = (len(continuous_columns) + n_cols - 1) // n_cols  # Calculate the number of rows needed

plt.figure(figsize=(15, n_rows * 5))
for i, col in enumerate(continuous_columns, 1):
    plt.subplot(n_rows, n_cols, i)
    plt.hist(df[col].dropna(), bins=20, edgecolor='k')
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Adjust grid size dynamically based on the number of continuous columns
n_cols = 4
n_rows = (len(continuous_columns) + n_cols - 1) // n_cols  # Calculate the number of rows needed

# Box Plots for Continuous Numeric Columns
plt.figure(figsize=(15, 10))
for i, col in enumerate(continuous_columns, 1):
    plt.subplot(n_rows, n_cols, i)
    plt.boxplot(df[col].dropna(), vert=False)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# For those missing hp values, what is the supertype?
df[df['hp'].isna()]['supertype'].value_counts()
# Out:
# supertype
# Trainer    3823
# Energy      549
# Name: count, dtype: int64

# %% [markdown]
# ### Object Columns

# %%
# Define object columns
object_columns = df.select_dtypes(include=['object']).columns

# %%
# Missing Values in Object Columns
missing_values = df[object_columns].isnull().sum()
# Plot Missing Values
plt.figure(figsize=(10, 5))
missing_values.plot(kind='bar', color='salmon')
plt.title('Missing Values in Object Columns')
plt.xlabel('Object Columns')
plt.ylabel('Number of Missing Values')
plt.show()

# %%
object_column_summary = summarize_object_columns(df)

# Print the summary of each object column
for col, summary in object_column_summary.items():
    print(f"Column: {col}")
    print(f"Unique Values Count: {summary['Unique Values Count']}")
    print("Top 5 Values and Counts:")
    for value, count in zip(summary['Top 5 Values'], summary['Top 5 Counts']):
        print(f"  {value}: {count}")
    print()
# Out:
# Column: card_type_id
# Unique Values Count: 29345
# Top 5 Values and Counts:
#   hgss4-1_holofoil: 1
#   xy5-143_reverseHolofoil: 1
#   swsh4-128_reverseHolofoil: 1
#   swsh4-128_holofoil: 1
#   sm7-129_reverseHolofoil: 1
#
# Column: name
# Unique Values Count: 4012
# Top 5 Values and Counts:
#   Pikachu: 148
#   Eevee: 95
#   Raichu: 77
#   Magnemite: 73
#   Charmander: 63
#
# Column: rarity
# Unique Values Count: 35
# Top 5 Values and Counts:
#   Common: 8608
#   Uncommon: 8276
#   Rare: 4446
#   Rare Holo: 2927
#   Promo: 1159
#
# Column: artist
# Unique Values Count: 343
# Top 5 Values and Counts:
#   5ban Graphics: 1910
#   Ken Sugimori: 1729
#   Kouki Saitou: 1204
#   Mitsuhiro Arita: 1143
#   Kagemaru Himeno: 1136
#
# Column: supertype
# Unique Values Count: 3
# Top 5 Values and Counts:
#   Pokémon: 24898
#   Trainer: 3898
#   Energy: 549
#
# Column: evolvesFrom
# Unique Values Count: 828
# Top 5 Values and Counts:
#   Eevee: 269
#   Pikachu: 95
#   Magnemite: 66
#   Magikarp: 65
#   Charmeleon: 63
#
# Column: flavorText
# Unique Values Count: 4805
# Top 5 Values and Counts:
#   Shaped like ancient writing, it is a huge mystery whether language or UNOWN came first.: 36
#   Strong electricity courses through the tips of its sharp claws. A light scratch causes fainting in foes.: 24
#   Its body is composed of plasma. It is known to infiltrate electronic devices and wreak havoc.: 23
#   This extremely rare Pokémon is a different color than usual. It is very hard to find.: 22
#   It is not satisfied unless it eats over 880 pounds of food every day. When it is done eating, it goes promptly to sleep.: 21
#
# Column: regulationMark
# Unique Values Count: 5
# Top 5 Values and Counts:
#   G: 2505
#   D: 1973
#   E: 1854
#   F: 1853
#   H: 738
#
# Column: rules
# Unique Values Count: 1703
# Top 5 Values and Counts:
#   V rule: When your Pokémon V is Knocked Out, your opponent takes 2 Prize cards.: 601
#   Pokémon-GX rule: When your Pokémon-GX is Knocked Out, your opponent takes 2 Prize cards.: 482
#   Pokémon-EX rule: When a Pokémon-EX has been Knocked Out, your opponent takes 2 Prize cards.: 338
#   Pokémon ex rule: When your Pokémon ex is Knocked Out, your opponent takes 2 Prize cards.: 259
#   VMAX rule: When your Pokémon VMAX is Knocked Out, your opponent takes 3 Prize cards.: 209
#
# Column: image_small
# Unique Values Count: 17905
# Top 5 Values and Counts:
#   https://images.pokemontcg.io/ex7/7.png: 3
#   https://images.pokemontcg.io/ex7/5.png: 3
#   https://images.pokemontcg.io/ex9/8.png: 3
#   https://images.pokemontcg.io/ex6/6.png: 3
#   https://images.pokemontcg.io/ex6/13.png: 3
#
# Column: image_large
# Unique Values Count: 17905
# Top 5 Values and Counts:
#   https://images.pokemontcg.io/ex7/7_hires.png: 3
#   https://images.pokemontcg.io/ex7/5_hires.png: 3
#   https://images.pokemontcg.io/ex9/8_hires.png: 3
#   https://images.pokemontcg.io/ex6/6_hires.png: 3
#   https://images.pokemontcg.io/ex6/13_hires.png: 3
#
# Column: set_id
# Unique Values Count: 160
# Top 5 Values and Counts:
#   swsh8: 501
#   sm12: 465
#   sm11: 457
#   sv2: 455
#   sv1: 444
#
# Column: set_name
# Unique Values Count: 160
# Top 5 Values and Counts:
#   Fusion Strike: 501
#   Cosmic Eclipse: 465
#   Unified Minds: 457
#   Paldea Evolved: 455
#   Scarlet & Violet: 444
#
# Column: set_series
# Unique Values Count: 16
# Top 5 Values and Counts:
#   Sword & Shield: 5701
#   Sun & Moon: 4848
#   EX: 3279
#   Scarlet & Violet: 3256
#   XY: 3247
#
# Column: set_releaseDate
# Unique Values Count: 142
# Top 5 Values and Counts:
#   2017/02/03: 553
#   2021/11/12: 501
#   2019/11/01: 465
#   2019/08/02: 457
#   2023/06/09: 455
#
# Column: set_updatedAt
# Unique Values Count: 45
# Top 5 Values and Counts:
#   2018/03/04 10:35:00: 5935
#   2020/08/14 09:35:00: 4941
#   2021/09/01 05:37:00: 1913
#   2019/01/28 16:44:00: 1352
#   2022/10/11 21:39:00: 1324
#
# Column: set_legalities_unlimited
# Unique Values Count: 1
# Top 5 Values and Counts:
#   Legal: 29345
#
# Column: set_legalities_expanded
# Unique Values Count: 1
# Top 5 Values and Counts:
#   Legal: 19755
#
# Column: set_legalities_standard
# Unique Values Count: 1
# Top 5 Values and Counts:
#   Legal: 7253
#
# Column: set_image_symbol
# Unique Values Count: 160
# Top 5 Values and Counts:
#   https://images.pokemontcg.io/swsh8/symbol.png: 501
#   https://images.pokemontcg.io/sm12/symbol.png: 465
#   https://images.pokemontcg.io/sm11/symbol.png: 457
#   https://images.pokemontcg.io/sv2/symbol.png: 455
#   https://images.pokemontcg.io/sv1/symbol.png: 444
#
# Column: set_image_logo
# Unique Values Count: 160
# Top 5 Values and Counts:
#   https://images.pokemontcg.io/swsh8/logo.png: 501
#   https://images.pokemontcg.io/sm12/logo.png: 465
#   https://images.pokemontcg.io/sm11/logo.png: 457
#   https://images.pokemontcg.io/sv2/logo.png: 455
#   https://images.pokemontcg.io/sv1/logo.png: 444
#
# Column: number
# Unique Values Count: 1748
# Top 5 Values and Counts:
#   3: 257
#   2: 253
#   4: 253
#   5: 249
#   8: 246
#
# Column: ancientTrait_name
# Unique Values Count: 10
# Top 5 Values and Counts:
#   Δ Evolution: 14
#   θ Stop: 13
#   Ω Barrier: 11
#   θ Double: 11
#   α Growth: 11
#
# Column: ancientTrait_text
# Unique Values Count: 10
# Top 5 Values and Counts:
#   You may play this card from your hand to evolve a Pokémon during your first turn or the turn you play that Pokémon.: 14
#   Prevent all effects of your opponent's Pokémon's Abilities done to this Pokémon.: 13
#   Whenever your opponent plays a Trainer card (excluding Pokémon Tools and Stadium cards), prevent all effects of that card done to this Pokémon.: 11
#   This Pokémon may have up to 2 Pokémon Tool cards attached to it.: 11
#   When you attach an Energy card from your hand to this Pokémon (except with an attack, Ability, or Trainer card), you may attach 2 Energy cards.: 11
#
# Column: type_1
# Unique Values Count: 11
# Top 5 Values and Counts:
#   Water: 3654
#   Grass: 3580
#   Psychic: 3359
#   Colorless: 3215
#   Fighting: 2799
#
# Column: type_2
# Unique Values Count: 8
# Top 5 Values and Counts:
#   Metal: 80
#   Darkness: 79
#   Water: 8
#   Psychic: 6
#   Grass: 4
#
# Column: subtype_1
# Unique Values Count: 24
# Top 5 Values and Counts:
#   Basic: 14297
#   Stage 1: 7727
#   Stage 2: 2470
#   Supporter: 1473
#   Item: 1302
#
# Column: subtype_2
# Unique Values Count: 24
# Top 5 Values and Counts:
#   V: 601
#   GX: 482
#   EX: 440
#   ex: 421
#   SP: 186
#
# Column: subtype_3
# Unique Values Count: 12
# Top 5 Values and Counts:
#   GX: 119
#   Ultra Beast: 59
#   ex: 55
#   Single Strike: 39
#   Rapid Strike: 37
#
# Column: subtype_4
# Unique Values Count: 2
# Top 5 Values and Counts:
#   Ultra Beast: 8
#   Rapid Strike: 4
#
# Column: price_type
# Unique Values Count: 5
# Top 5 Values and Counts:
#   reverseHolofoil: 11369
#   normal: 10507
#   holofoil: 6378
#   unknown: 928
#   firstEditionHolofoil: 163

# %% [markdown]
# ## Inspecting each column

# %% [markdown]
# Additional views of the data

# %%
#name
df[df['name'].str.startswith('Charizard')]['name'].unique() # There multiple types of Charizard
# Out:
# array(['Charizard', 'Charizard δ', 'Charizard-GX', 'Charizard-EX',
#        'Charizard G', 'Charizard & Braixen-GX', 'Charizard V',
#        'Charizard VMAX', 'Charizard G LV.X', 'Charizard Spirit Link',
#        'Charizard ex', 'Charizard ★ δ', 'Charizard VSTAR'], dtype=object)

# %%
df['rarity'].unique()
# Out:
# array(['Rare Holo', 'Common', nan, 'Rare Holo GX', 'Rare', 'Uncommon',
#        'Rare Holo V', 'Promo', 'Rare Holo EX', 'Rare Ultra', 'Rare BREAK',
#        'Rare Shiny', 'Rare Prism Star', 'Rare Holo VMAX', 'Amazing Rare',
#        'Rare Shining', 'Rare Shiny GX', 'Rare Rainbow', 'Rare Secret',
#        'Rare Prime', 'Rare ACE', 'Rare Holo Star', 'LEGEND',
#        'Rare Holo LV.X', 'Classic Collection', 'Rare Holo VSTAR',
#        'Trainer Gallery Rare Holo', 'Radiant Rare', 'Double Rare',
#        'Illustration Rare', 'Ultra Rare', 'Special Illustration Rare',
#        'Hyper Rare', 'Shiny Rare', 'Shiny Ultra Rare', 'ACE SPEC Rare'],
#       dtype=object)

# %% [markdown]
# Types

# %%
# List of type columns
type_columns = ['type_1', 'type_2']
# Plot value counts for each type column
plot_counts(df, type_columns, 'Value Counts of Types')

# %% [markdown]
# Subtypes

# %%
# List of subtype columns
subtype_columns = ['subtype_1', 'subtype_2', 'subtype_3', 'subtype_4']
# Plot value counts for each subtype column
plot_counts(df, subtype_columns, 'Value Counts of Subtypes')

# %% [markdown]
# Abilities, Weaknesses and Resistance

# %% [markdown]
# Prices - I want to check how many prices could be filled for those that do not have a market price

# %%
# This will check for the number of rows that do not have a market price but do have a price filled in another price category
df[df['market'].isnull() & (df['low'].notnull() |df['mid'].notnull() |df['high'].notnull() |df['directLow'].notnull())].shape[0]
# Out:
# 85

# %% [markdown]
# # Clean Data

# %% [markdown]
# ## Deal with Missing Values

# %%
clean_df = df.copy()

# Fill values with 'Unknown'
fill_unknowns_columns = ['rarity','artist','evolvesFrom','regulationMark','set_legalities_expanded','set_legalities_standard',
                   'ancientTrait_name','type_1','type_2','subtype_1','subtype_2','subtype_3','subtype_4','nationalPokedexNumber']
# Fill values with 0
fill_zeros = ['hp','convertedRetreatCost', 'num_abilities', 'num_attacks', 'num_resistances', 'num_weaknesses']

clean_df[fill_unknowns_columns] = clean_df[fill_unknowns_columns].fillna('Unknown')
clean_df[fill_zeros] = clean_df[fill_zeros].fillna(0)

# %% [markdown]
# For any missing market prices, will fill in with mid, then average of low and high, then low, than high prices. There were only 85 that could be filled so for the rest, there are not prices at all. Will drop the price_type, low, mid, high and directLow prices and use just the market price moving forward.

# %% [markdown]
# After filling prices

# %%
# Prices
print(f"Missing 'market' prices before filling: {clean_df['market'].isnull().sum()}")

# Fill missing 'market' prices using the given strategy
clean_df['market'] = (clean_df['market'].fillna(clean_df['mid'])
                           .fillna(clean_df[['low', 'high']].mean(axis=1))
                           .fillna(clean_df['low'])
                           .fillna(clean_df['high']))
print(f"Missing 'market' prices after filling: {clean_df['market'].isnull().sum()}")

# Fill remaining NA values with the median of the 'market' column within each 'price_type' group
clean_df['market'] = clean_df.groupby('price_type')['market'].transform(lambda x: x.fillna(x.median()))

# For those with unknown price type fill values with the overall median of the 'market' column
clean_df['market'] = clean_df['market'].fillna(clean_df['market'].median())

print(f"Missing 'market' prices after filling with median by price_type: {clean_df['market'].isnull().sum()}")

# Create price_bucket column
clean_df['price_bucket'] = clean_df['market'].apply(lambda x: 'low' if x < 50 else 'high')
# Out:
# Missing 'market' prices before filling: 1013
# Missing 'market' prices after filling: 928
# Missing 'market' prices after filling with median by price_type: 0
# c:\Source\pokemon_value_analysis\venv\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
# Year
# Convert set_releaseDate to datetime
clean_df['set_releaseDate'] = pd.to_datetime(clean_df['set_releaseDate'], format='%Y/%m/%d', errors='coerce')
# Extract year from set_releaseDate
clean_df['release_year'] = clean_df['set_releaseDate'].dt.year

# %% [markdown]
# ## Drop Columns

# %%
# these seem redundant or not useful: 'set_updatedAt', 'set_id', 'set_legalities_unlimited', 'set_releaseDate' # after we extract year
# these are large text fields that I will not use for this analysis: 'flavorText', 'rules','ancientTrait_text',
# image fields we won't use for this analysis: 'image_small', 'image_large', 'set_image_symbol','set_image_logo'
# price fields we won't use for this analysis: 'price_type','low', 'mid', 'high', 'directLow'
columns_to_drop = ['set_updatedAt', 'set_releaseDate', 'set_id','flavorText', 'rules','ancientTrait_text', 'set_legalities_unlimited',
                   'image_small', 'image_large', 'set_image_symbol','set_image_logo','low', 'mid', 'high', 'directLow']
clean_df = clean_df.drop(columns=columns_to_drop)

# %% [markdown]
# ## Clean Formatting

# %%
# Columns to convert to integers
int_columns = [
    'hp', 
    'convertedRetreatCost', 
    'set_printedTotal', 
    'set_total',
    'num_abilities', 
    'num_attacks',
    'num_resistances', 
    'num_weaknesses'
]

for col in int_columns:
    clean_df[col] = clean_df[col].astype('Int64')

# %%
summarize_df(clean_df)
# Out:
#                      Column  Non-Null Count  Missing Values  \
# 0              card_type_id           29345               0
# 1                      name           29345               0
# 2                        hp           29345               0
# 3                    rarity           29345               0
# 4                    artist           29345               0
# 5                 supertype           29345               0
# 6               evolvesFrom           29345               0
# 7      convertedRetreatCost           29345               0
# 8            regulationMark           29345               0
# 9                  set_name           29345               0
# 10               set_series           29345               0
# 11         set_printedTotal           29345               0
# 12                set_total           29345               0
# 13  set_legalities_expanded           29345               0
# 14  set_legalities_standard           29345               0
# 15                   number           29345               0
# 16        ancientTrait_name           29345               0
# 17                   type_1           29345               0
# 18                   type_2           29345               0
# 19                subtype_1           29345               0
# 20                subtype_2           29345               0
# 21                subtype_3           29345               0
# 22                subtype_4           29345               0
# 23    nationalPokedexNumber           29345               0
# 24            num_abilities           29345               0
# 25              num_attacks           29345               0
# 26          num_resistances           29345               0
# 27           num_weaknesses           29345               0
# 28               price_type           29345               0
# 29                   market           29345               0
# 30             price_bucket           29345               0
# 31             release_year           29345               0
#
#     Missing Values (%)    Dtype  Unique Values
# 0                  0.0   object          29345
# 1                  0.0   object           4012
# 2                  0.0    Int64             33
# 3                  0.0   object             36
# 4                  0.0   object            344
# 5                  0.0   object              3
# 6                  0.0   object            829
# 7                  0.0    Int64              6
# 8                  0.0   object              6
# 9                  0.0   object            160
# 10                 0.0   object             16
# 11                 0.0    Int64             91
# 12                 0.0    Int64            101
# 13                 0.0   object              2
# 14                 0.0   object              2
# 15                 0.0   object           1748
# 16                 0.0   object             11
# 17                 0.0   object             12
# 18                 0.0   object              9
# 19                 0.0   object             25
# 20                 0.0   object             25
# 21                 0.0   object             13
# 22                 0.0   object              3
# 23                 0.0   object           1011
# 24                 0.0    Int64              4
# 25                 0.0    Int64              5
# 26                 0.0    Int64              3
# 27                 0.0    Int64              3
# 28                 0.0   object              5
# 29                 0.0  float64           3319
# 30                 0.0   object              2
# 31                 0.0    int32             26

# %% [markdown]
# # Visualize Clean DF

# %%
# Numeric columns described
clean_df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#                  hp convertedRetreatCost set_printedTotal     set_total  \
# count  29345.000000         29345.000000     29345.000000  29345.000000
# mean      82.739819             1.336718       143.894701    160.748645
# std       59.832246             1.013471        52.868999     64.543106
# min        0.000000             0.000000         5.000000      5.000000
# 25%       50.000000             1.000000       106.000000    110.000000
# 50%       70.000000             1.000000       135.000000    146.000000
# 75%      110.000000             2.000000       185.000000    216.000000
# max      340.000000             5.000000       307.000000    304.000000
#
#       num_abilities   num_attacks num_resistances num_weaknesses  \
# count  29345.000000  29345.000000    29345.000000   29345.000000
# mean       0.189061      1.387766        0.249208       0.829818
# std        0.393561      0.753459        0.439827       0.379230
# min        0.000000      0.000000        0.000000       0.000000
# 25%        0.000000      1.000000        0.000000       1.000000
# 50%        0.000000      2.000000        0.000000       1.000000
# 75%        0.000000      2.000000        0.000000       1.000000
# max        3.000000      4.000000        2.000000       2.000000
#
#              market  release_year
# count  29345.000000  29345.000000
# mean       8.334623   2014.236361
# std       80.469444      7.074206
# min        0.010000   1999.000000
# 25%        0.180000   2008.000000
# 50%        0.500000   2016.000000
# 75%        2.690000   2020.000000
# max     8880.300000   2024.000000

# %% [markdown]
# ## By Year Views

# %%
# Plot market prices by year
plot_prices(clean_df)

# %%
# Aggregating data by card_id, release_year, and rarity
aggregated_data = clean_df.groupby(['card_type_id', 'release_year', 'rarity']).size().reset_index(name='count')

# Aggregating card counts by release year and rarity
rarity_per_year = aggregated_data.groupby(['release_year', 'rarity']).size().unstack(fill_value=0)

# Plotting Count of Cards by Rarity Per Year
plt.figure(figsize=(15, 10))
rarity_per_year.plot(kind='bar', stacked=True, figsize=(15, 10), colormap='tab20')
plt.title('Count of Cards by Rarity Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Aggregating data by card_id, release_year, and supertype
aggregated_supertype_data = clean_df.groupby(['card_type_id', 'release_year', 'supertype']).size().reset_index(name='count')

# Aggregating card counts by release year and supertype
supertype_per_year = aggregated_supertype_data.groupby(['release_year', 'supertype']).size().unstack(fill_value=0)

# Plotting Count of Cards by Supertype Per Year
plt.figure(figsize=(15, 10))
supertype_per_year.plot(kind='bar', stacked=True, figsize=(15, 10), colormap='tab20')
plt.title('Count of Cards by Supertype Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Aggregating card counts by release year and type_1 without price_type
type_per_year = clean_df.groupby(['release_year', 'type_1']).size().unstack(fill_value=0)

# Plotting Count of Cards by Type_1 Per Year
plt.figure(figsize=(15, 10))
type_per_year.plot(kind='bar', stacked=True, figsize=(15, 10), colormap='tab20')
plt.title('Count of Cards by Type_1 Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Aggregating data by card_id, release_year, and type_1
aggregated_type_data = clean_df.groupby(['card_type_id', 'release_year', 'type_1']).size().reset_index(name='count')

# Aggregating card counts by release year and type_1
type_per_year = aggregated_type_data.groupby(['release_year', 'type_1']).size().unstack(fill_value=0)

# Plotting Count of Cards by Type_1 Per Year
plt.figure(figsize=(15, 10))
type_per_year.plot(kind='bar', stacked=True, figsize=(15, 10), colormap='tab20')
plt.title('Count of Cards by Type_1 Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate with Price Buckets

# %%
# Aggregating card counts by release year and price_bucket
bucket_per_year = clean_df.groupby(['release_year', 'price_bucket']).size().unstack(fill_value=0)

# Plotting Count of Cards by Price Bucket Per Year
plt.figure(figsize=(15, 10))
bucket_per_year.plot(kind='bar', stacked=True, figsize=(15, 10), colormap='tab20')
plt.title('Count of Cards by Price Bucket Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Normalize by total counts to get proportions
bucket_per_year_proportion = bucket_per_year.div(bucket_per_year.sum(axis=1), axis=0) * 100

# Plotting Proportion of Cards by Price Bucket Per Year
plt.figure(figsize=(15, 10))
bucket_per_year_proportion.plot(kind='bar', stacked=True, figsize=(15, 10), colormap='tab20')
plt.title('Proportion of Cards by Price Bucket Per Year')
plt.xlabel('Year')
plt.ylabel('Proportion (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# List of columns to evaluate
columns_to_evaluate = ['hp', 'rarity', 'supertype', 'convertedRetreatCost', 'regulationMark','set_series',  
                       'set_legalities_expanded','set_legalities_standard', 'ancientTrait_name', 'type_1', 'type_2', 'subtype_1', 
                       'subtype_2', 'subtype_3', 'subtype_4','num_abilities', 'num_attacks','num_resistances', 'num_weaknesses', 'price_type']

for col in columns_to_evaluate:
    print(f"Column: {col}")
    plot_price_buckets(clean_df, [col], show_proportion=False) # Show counts
    plot_price_buckets(clean_df, [col], show_proportion=True) # Show proportions
# Out:
# Column: hp
# Column: rarity
# Column: supertype
# Column: convertedRetreatCost
# Column: regulationMark
# Column: set_series
# Column: set_legalities_expanded
# Column: set_legalities_standard
# Column: ancientTrait_name
# Column: type_1
# Column: type_2
# Column: subtype_1
# Column: subtype_2
# Column: subtype_3
# Column: subtype_4
# Column: num_abilities
# Column: num_attacks
# Column: num_resistances
# Column: num_weaknesses
# Column: price_type

# %% [markdown]
# ## Drop Columns After Visualization

# %% [markdown]
# ### Evaluation of those filled with 'Unknown'

# %%
# Initialize an empty list to store the results
results = []

# List of columns that were originally filled with 'Unknown'
original_na_columns = clean_df.columns[clean_df.isin(['Unknown']).any()]

for column in original_na_columns:
    # Calculate the original proportion of 'Unknown' values
    unknown_count = (clean_df[column] == 'Unknown').sum()
    unknown_proportion = (unknown_count / len(clean_df) * 100).round(2)
    
    # Calculate the proportion of 'high' price buckets within the filled values
    filled_values = clean_df[clean_df[column] != 'Unknown']
    high_price_proportion = ((filled_values['price_bucket'] == 'high').mean() * 100).round(2)
    
    # Append the results to the list
    results.append({
        'Column': column,
        'Proportion of Unknown Values (%)': unknown_proportion,
        'Proportion of High Price Bucket in Filled Values (%)': high_price_proportion
    })

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results)

# %%
# Dropping columns with more than 30% unknown values
results_df[results_df['Proportion of Unknown Values (%)'] > 30]['Column'].unique()
# Out:
# array(['evolvesFrom', 'regulationMark', 'set_legalities_expanded',
#        'set_legalities_standard', 'ancientTrait_name', 'type_2',
#        'subtype_2', 'subtype_3', 'subtype_4'], dtype=object)

# %%
# Dropping columns with more than 30% unknown values since they did not seem to have a significant impact on the price bucket
columns_to_drop = results_df[results_df['Proportion of Unknown Values (%)'] > 30]['Column'].unique()
clean_df = clean_df.drop(columns=columns_to_drop, axis=1)

# %% [markdown]
# ### Additional Columns to Drop

# %%
clean_df.columns
# Out:
# Index(['card_type_id', 'name', 'hp', 'rarity', 'artist', 'supertype',
#        'convertedRetreatCost', 'set_name', 'set_series', 'set_printedTotal',
#        'set_total', 'number', 'type_1', 'subtype_1', 'nationalPokedexNumber',
#        'num_abilities', 'num_attacks', 'num_resistances', 'num_weaknesses',
#        'price_type', 'market', 'price_bucket', 'release_year'],
#       dtype='object')

# %%
# Additional columns to drop
columns_to_drop = ['set_total', 'set_printedTotal','market'] # we no longer need market price as we will use price_bucket, 
# set_total and set_printedTotal seem to be redundant

clean_df = clean_df.drop(columns=columns_to_drop)

# %%
summarize_df(clean_df)
# Out:
#                    Column  Non-Null Count  Missing Values  Missing Values (%)  \
# 0            card_type_id           29345               0                 0.0
# 1                    name           29345               0                 0.0
# 2                      hp           29345               0                 0.0
# 3                  rarity           29345               0                 0.0
# 4                  artist           29345               0                 0.0
# 5               supertype           29345               0                 0.0
# 6    convertedRetreatCost           29345               0                 0.0
# 7                set_name           29345               0                 0.0
# 8              set_series           29345               0                 0.0
# 9                  number           29345               0                 0.0
# 10                 type_1           29345               0                 0.0
# 11              subtype_1           29345               0                 0.0
# 12  nationalPokedexNumber           29345               0                 0.0
# 13          num_abilities           29345               0                 0.0
# 14            num_attacks           29345               0                 0.0
# 15        num_resistances           29345               0                 0.0
# 16         num_weaknesses           29345               0                 0.0
# 17             price_type           29345               0                 0.0
# 18           price_bucket           29345               0                 0.0
# 19           release_year           29345               0                 0.0
#
#      Dtype  Unique Values
# 0   object          29345
# 1   object           4012
# 2    Int64             33
# 3   object             36
# 4   object            344
# 5   object              3
# 6    Int64              6
# 7   object            160
# 8   object             16
# 9   object           1748
# 10  object             12
# 11  object             25
# 12  object           1011
# 13   Int64              4
# 14   Int64              5
# 15   Int64              3
# 16   Int64              3
# 17  object              5
# 18  object              2
# 19   int32             26

# %% [markdown]
# # Create Cleaned DF

# %%
clean_df.to_csv('data/cleaned_pokemon_data.csv', index=False)
